# %%
# libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')
df.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.hist(figsize=(20,20));

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ### Train Test and Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X_train_DT, X_test_DT, y_train_DT, y_test_DT = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
dtree.fit(X_train_DT, y_train_DT)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ### Prediction and Evaluation

# %%
test_predictions_DT = dtree.predict(X_test_DT)

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics

# %%
print(classification_report(y_test_DT, test_predictions_DT))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85306
#            1       0.74      0.76      0.75       137
#
#     accuracy                           1.00     85443
#    macro avg       0.87      0.88      0.88     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(confusion_matrix(y_test_DT, test_predictions_DT))
# Out:
# [[85270    36]
#  [   33   104]]

# %%
#scores
print("Accuracy DT:",metrics.accuracy_score(y_test_DT, test_predictions_DT))
print("Precision DT:",metrics.precision_score(y_test_DT, test_predictions_DT))
print("Recall DT:",metrics.recall_score(y_test_DT, test_predictions_DT))
print("F1 Score DT:",metrics.f1_score(y_test_DT, test_predictions_DT))
# Out:
# Accuracy DT: 0.9991924440855307
# Precision DT: 0.7428571428571429
# Recall DT: 0.7591240875912408
# F1 Score DT: 0.7509025270758123

# %%
from sklearn import tree
plt.figure(figsize=(20,25))
tree.plot_tree(dtree,feature_names=X.columns,class_names=['Class-1', 'Class-0'],rounded=True, # Rounded node edges
          filled=True, # Adds color according to class
          proportion=True
        )
plt.show()

# %% [markdown]
# # K nearest neighbor

# %% [markdown]
# ## EDA

# %%
df.describe().transpose()
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
#sns.pairplot(df, hue='Class')

# %%
#sns.pairplot(df,hue='Class',palette='Set1')

# %%
#if 'Type' in CC.columns:
   # sns.pairplot(CC, hue='Type')
#elif 'Class' in CC.columns:  # If 'Class' is the actual column name
#    sns.pairplot(CC, hue='Class')
#else:
#    print("Error: Column 'Type' or 'Class' not found in the dataset.")

# %% [markdown]
# ## K nearest Neighbour

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = pd.DataFrame(scaler.fit_transform(df.drop(["Class"],axis = 1)))
y = df.Class

# %%
X.head(4)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.193679  0.082637  0.331128  ...  0.326118 -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ... -0.089611 -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...  0.680975  0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ... -0.269855 -0.147443  0.007267 -0.304777
#
#          24        25        26        27        28        29
# 0  0.110507  0.246585 -0.392170  0.330892 -0.063781  0.244964
# 1 -0.561131  0.320694  0.261069 -0.022256  0.044608 -0.342475
# ...

# %%
X_train_knn, X_test_knn, y_train_knn, y_test_knn = train_test_split(X,y,test_size=0.30)

# %% [markdown]
# ### Using KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
model_knn = knn.fit(X_train_knn, y_train_knn)

# %%
model_knn
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test_knn)

# %% [markdown]
# ### Predictions and Evaluations

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test_knn,pred))
# Out:
# [[85255    18]
#  [   29   141]]

# %%
print(classification_report(y_test_knn,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85273
#            1       0.89      0.83      0.86       170
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.91      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
error_rate = []

# Will take some time
for i in range(1,40):

    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_knn,y_train_knn)
    pred_i = knn.predict(X_test_knn)
    error_rate.append(np.mean(pred_i != y_test_knn))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
#Orginal K=1
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train_knn,y_train_knn)
pred = knn.predict(X_test_knn)

print('WITH k=1')
print('\n')
print(confusion_matrix(y_test_knn,pred))
print('\n')
print(classification_report(y_test_knn,pred))
# Out:
# WITH k=1
#
#
# [[85255    18]
#  [   29   141]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85273
#            1       0.89      0.83      0.86       170
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.91      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy on training data
X_train_prediction_knn = model_knn.predict(X_train_knn)
training_data_accuracy = accuracy_score(X_train_prediction_knn, y_train_knn)

# %%
# accuracy on testing data
X_test_prediction_knn = model_knn.predict(X_test_knn)
test_data_accuracy = accuracy_score(X_test_prediction_knn, y_test_knn)

# %%
#scores
print("Accuracy KNN:",metrics.accuracy_score(y_test_knn, X_test_prediction_knn))
print("Precision KNN:",metrics.precision_score(y_test_knn, X_test_prediction_knn))
print("Recall KNN:",metrics.recall_score(y_test_knn, X_test_prediction_knn))
print("F1 Score KNN:",metrics.f1_score(y_test_knn, X_test_prediction_knn))
# Out:
# Accuracy KNN: 0.9994499256814484
# Precision KNN: 0.8867924528301887
# Recall KNN: 0.8294117647058824
# F1 Score KNN: 0.8571428571428571

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### EDA

# %%
# distribution of legit transactions & fraudulent transactions
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# separating the data for analysis
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_data = pd.concat([legit_sample, fraud], axis=0)

# %%
new_data.head(4)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 40354    40206.0  1.505489 -0.572398 -1.732821 -1.828074  1.847776  2.903257
# 211470  138427.0 -1.970198 -0.978736  0.827036 -1.285497 -1.211081  1.443887
# 32021    36607.0  1.238236  0.308226  0.130543  0.557570  0.005557 -0.392919
# 17671    28844.0 -2.386685  2.805485 -3.039428  0.932365  0.713066 -1.432425
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 40354  -0.671467  0.607996 -1.229009  ...  0.182751  0.331239 -0.222024
# 211470  1.812596  0.030838  0.843159  ... -0.028111  0.146070  0.031088
# 32021   0.013149 -0.051948  0.027493  ... -0.281555 -0.767880  0.112160
# 17671   2.222616 -1.169636  3.030226  ... -1.063154 -0.336137  0.001864
#
#              V24       V25       V26       V27       V28  Amount  Class
# 40354   1.053871  0.974314 -0.023879 -0.022316 -0.004923   11.00      0
# 211470  0.171652  0.048485 -0.620817  0.033379  0.306160  511.91      0
# ...

# %%
new_data.tail(4)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95491.491870 -0.122179  0.105670 -0.014175 -0.029972 -0.007588
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.008034  0.034075 -0.044093  0.010110  ... -0.016227 -0.007410
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.014631  0.020830  0.023796  0.029434  0.005173  0.028279  0.025332
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       86.666911
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_data.drop(columns='Class', axis=1)
Y = new_data['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 40354    40206.0  1.505489 -0.572398 -1.732821 -1.828074  1.847776  2.903257
# 211470  138427.0 -1.970198 -0.978736  0.827036 -1.285497 -1.211081  1.443887
# 32021    36607.0  1.238236  0.308226  0.130543  0.557570  0.005557 -0.392919
# 17671    28844.0 -2.386685  2.805485 -3.039428  0.932365  0.713066 -1.432425
# 197339  131964.0 -2.319435 -2.389440 -0.909395 -0.629911  0.642708  0.614993
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 40354     0
# 211470    0
# 32021     0
# 17671     0
# 197339    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# ### Using Logistic Regression - split the data into training and testing data

# %%
X_train_lr, X_test_lr, Y_train_lr , Y_test_lr = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train_lr.shape, X_test_lr.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
# training the Logistic Regression Model with Training Data
model_lr = LogisticRegression()

# %%
model_lr.fit(X_train_lr, Y_train_lr)
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction_lr = model_lr.predict(X_train_lr)
training_data_accuracy = accuracy_score(X_train_prediction_lr, Y_train_lr)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9428208386277002

# %%
# accuracy on test data
X_test_prediction_lr = model_lr.predict(X_test_lr)
test_data_accuracy = accuracy_score(X_test_prediction_lr, Y_test_lr)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9137055837563451

# %% [markdown]
# ### Evaluating Model

# %%
#scores
print("Accuracy LR:",metrics.accuracy_score(Y_test_lr, X_test_prediction_lr))
print("Precision LR:",metrics.precision_score(Y_test_lr, X_test_prediction_lr))
print("Recall LR:",metrics.recall_score(Y_test_lr, X_test_prediction_lr))
print("F1 Score LR:",metrics.f1_score(Y_test_lr, X_test_prediction_lr))
# Out:
# Accuracy LR: 0.9137055837563451
# Precision LR: 0.9354838709677419
# Recall LR: 0.8877551020408163
# F1 Score LR: 0.9109947643979057

# %% [markdown]
# # Support Vector Machine

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df = df.drop("Time", axis=1)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()

# %%
#standard scaling
df['std_Amount'] = scaler.fit_transform(df['Amount'].values.reshape (-1,1))

#removing Amount
df = df.drop("Amount", axis=1)

# %%
sns.countplot(x="Class", data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
import imblearn 
from imblearn.under_sampling import RandomUnderSampler 

undersample = RandomUnderSampler(sampling_strategy=0.5)

# %%
cols = df.columns.tolist()
cols = [c for c in cols if c not in ["Class"]]
target = "Class"

# %%
#define X and Y
X = df[cols]
Y = df[target]

#undersample
X_under, Y_under = undersample.fit_resample(X, Y)

# %%
from pandas import DataFrame
test = pd.DataFrame(Y_under, columns = ['Class'])

# %%
#visualizing undersampling results
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=df, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_under, Y_under, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
#train the model
model2 = SVC(probability=True, random_state=2)
svm = model2.fit(X_train, y_train)

# %%
#predictions
y_pred_svm = model2.predict(X_test)

# %%
print("Accuracy SVM:",metrics.accuracy_score(y_test, y_pred_svm))
print("Precision SVM:",metrics.precision_score(y_test, y_pred_svm))
print("Recall SVM:",metrics.recall_score(y_test, y_pred_svm))
print("F1 Score SVM:",metrics.f1_score(y_test, y_pred_svm))
# Out:
# Accuracy SVM: 0.9358108108108109
# Precision SVM: 0.9587628865979382
# Recall SVM: 0.8611111111111112
# F1 Score SVM: 0.9073170731707317

# %%
#CM matrix
matrix_svm = confusion_matrix(y_test, y_pred_svm)
cm_svm = pd.DataFrame(matrix_svm, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm_svm, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix SVM"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %%
#AUC
y_pred_svm_proba = model2.predict_proba(X_test)[::,1]
fpr_svm, tpr_svm, _ = metrics.roc_curve(y_test,  y_pred_svm_proba)
auc_svm = metrics.roc_auc_score(y_test, y_pred_svm_proba)
print("AUC SVM :", auc_svm)
# Out:
# AUC SVM : 0.9733057525610718

# %%
#ROC
plt.plot(fpr_svm,tpr_svm,label="SVM, auc={:.3f})".format(auc_svm))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('SVM ROC curve')
plt.legend(loc=4)
plt.show()

# %%
svm_precision, svm_recall, _ = precision_recall_curve(y_test, y_pred_svm_proba)
no_skill = len(y_test[y_test==1]) / len(y_test)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', color='black', label='No Skill')
plt.plot(svm_recall, svm_precision, color='orange', label='SVM')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.legend()
plt.show()
